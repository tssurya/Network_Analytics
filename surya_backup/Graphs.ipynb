# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab

fig, ax1 = plt.subplots()
t = [1, 2, 4, 8, 16, 24]
s1 = [80.6, 40.8, 21.0, 10.7, 5.80, 3.90]
s_max = [81, 41.4, 21.5, 11, 6, 4]
s_min = [80.2, 40.2, 20.5, 10.4, 5.6, 3.8 ]
s3 = [80.6, (80.6/2), 80.6/4, 80.6/8, 80.6/16, 80.6/24]
ax1.plot(t, s1, 'b-')
ax1.plot(t, s1, 'b.')

ax1.plot(t, s_max, 'b-' )
#ax1.plot(t, s_min, 'y.' )

ax1.plot(t, s3, 'y--')
ax1.plot(t, s3, 'y--')

ax1.set_xlabel('number of cores')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('training time (in secs)', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim([0,90])


ax2 = ax1.twinx()
s2 = [10.8, 10.7, 10.8, 10.8, 10.9, 10.9]
ax2.plot(t, s2, 'r-')
ax2.plot(t, s2, 'r-*')

ax2.set_ylabel('NMAE(in %)', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.ylim([0,20])
#pyplot.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab

fig, ax1 = plt.subplots()
t = [1, 2, 4, 8, 16, 24]
s1 = [4179.7, 2222.2, 1104.0, 573.7, 414.5, 288.5]
s3 = [4179.7/1, 4179.7/2, 4179.7/4, 4179.7/8, 4179.7/16, 4179.7/24 ]
ax1.plot(t, s1, 'b-')
ax1.plot(t, s1, 'b.')
ax1.plot(t, s3, 'y--')
ax1.set_xlabel('number of cores')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('training time (in secs)', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim([0,4500])


ax2 = ax1.twinx()
s2 = [2.10, 2.11, 2.09, 2.12, 2.13, 2.13]
ax2.plot(t, s2, 'r-')
ax2.plot(t, s2, 'r-*')
ax2.set_ylabel('NMAE(in %)', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.ylim([0,5])
#pyplot.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab

fig, ax1 = plt.subplots()
t = [1, 2, 4, 8, 16, 24]
s1 = [2321.2, 1766.4, 1169.7, 1024, 834, 773.2]
s3 = [2321.2/1, 2321.2/2, 2321.2/4, 2321.2/8, 2321.2/16, 2321.2/24 ]
ax1.plot(t, s1, 'b-')
ax1.plot(t, s1, 'b-*')
ax1.plot(t, s3, 'y--')
ax1.set_xlabel('number of cores')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('training time (in secs)', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim([0,2500])


ax2 = ax1.twinx()
s2 = [2.33, 2.38, 2.35, 2.32, 2.39, 2.33]
ax2.plot(t, s2, 'r-')
ax2.plot(t, s2, 'r-*')
ax2.set_ylabel('NMAE(in %)', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.ylim([0,5])
#pyplot.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab

fig, ax1 = plt.subplots()
t = [1, 2, 4, 8, 16, 24]
s1 = [39.7, 40.1, 38.1, 37.9, 39.2, 40.7]
s3 = [39.7/1, 39.7/2, 39.7/4, 39.7/8, 39.7/16, 39.7/24 ]
ax1.plot(t, s1, 'b-')
ax1.plot(t, s1, 'b.')
ax1.plot(t, s3, 'y--')
ax1.set_xlabel('number of cores')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('training time (in secs)', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim([0,60])


ax2 = ax1.twinx()
s2 = [11.5, 11.7, 11.7, 11.5, 11.4, 11.5]
ax2.plot(t, s2, 'r-')
ax2.plot(t, s2, 'r*')
ax2.set_ylabel('NMAE(in %)', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.ylim([0,20])
#pyplot.legend()
plt.show()

# %%
#Univariate Feature Selection

import numpy as np
import matplotlib.pyplot as plt
import pylab

fig, ax1 = plt.subplots()
t = [5, 10, 50, 100]
s1 = [10.27, 10.21, 10.27, 9.6]
s3 = [1.11, 1.75, 8.13, 16.33 ]
ax1.plot(t, s1, 'b-')
ax1.plot(t, s1, 'b-')

ax1.plot(t, s1, 'b.')

#ax1.plot(t, s3, 'g-*')
ax1.set_xlabel('number of features (k)')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('preprocessing time (in secs)', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim([0,20])
plt.xlim([0,105])


ax2 = ax1.twinx()
s2 = [2.42, 2.34, 2.27, 2.22]
ax2.plot(t, s2, 'r-')
ax2.plot(t, s2, 'r-*')
ax2.set_ylabel('NMAE(in %)', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.ylim([0,5])
plt.xlim([0,105])

#pyplot.legend()
plt.show()

# %%
#Stability Feature Selection

import numpy as np
import matplotlib.pyplot as plt
import pylab

fig, ax1 = plt.subplots()
t = [5, 10, 50, 100]
s1 = [6097.64, 6117 , 5989.8, 6134.2]
s3 = [1.11, 1.75, 8.13, 16.33 ]
ax1.plot(t, s1, 'b-')
ax1.plot(t, s1, 'b-')

ax1.plot(t, s1, 'b.')

#ax1.plot(t, s3, 'g-*')
ax1.set_xlabel('number of features (k)')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('preprocessing time (in secs)', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim([0,7000])
plt.xlim([0,105])


ax2 = ax1.twinx()
s2 = [3.04, 2.68, 2.20, 2.12]
ax2.plot(t, s2, 'r-')
ax2.plot(t, s2, 'r-*')
ax2.set_ylabel('NMAE(in %)', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.ylim([0,5])
plt.xlim([0,105])

#pyplot.legend()
plt.show()

# %%
#Forward Feature Selection

import numpy as np
import matplotlib.pyplot as plt
import pylab

fig, ax1 = plt.subplots()
t = [5, 10, 50]
s1 = [453, 1444.7 , 25095]
#s3 = [1.11, 1.75, 8.13, 16.33 ]
ax1.plot(t, s1, 'b-')
ax1.plot(t, s1, 'b.')

#ax1.plot(t, s3, 'g-*')
ax1.set_xlabel('number of features (k)')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('preprocessing time (in secs)', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim([0,26000])
#plt.xlim([55])


ax2 = ax1.twinx()
s2 = [2.29, 2.21, 2.13]
ax2.plot(t, s2, 'r-')
ax2.plot(t, s2, 'r-*')
ax2.set_ylabel('NMAE(in %)', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.ylim([0,5])
plt.xlim([0,55])

#pyplot.legend()
plt.show()

# %%
#Forward Feature Selection

import numpy as np
import matplotlib.pyplot as plt
import pylab

fig, ax1 = plt.subplots()
t = [5, 10, 50]
s1 = [10.27, 10.21, 10.27]
s2 = [6097.64 , 6117, 5989.86]
s3 = [453, 1444.7 , 25095]

#s3 = [1.11, 1.75, 8.13, 16.33 ]
ax1.plot(t, s1, 'b-')
ax1.plot(t, s1, 'b.')
ax1.plot(t, s2, 'r-')
ax1.plot(t, s2, 'r.')
ax1.plot(t, s3, 'g-')
ax1.plot(t, s3, 'g.')

#ax1.plot(t, s3, 'g-*')
ax1.set_xlabel('number of features (k)')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('preprocessing time (in secs)', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim([-1000,26000])
plt.xlim([0, 55])




#pyplot.legend()
plt.show()
